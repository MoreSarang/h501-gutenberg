# %%
# Show available Conda envs to verify environment setup
# !conda env list

import pandas as pd
from tt_gutenberg.authors import list_authors

# Load datasets
authors = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-06-03/gutenberg_authors.csv")
languages = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-06-03/gutenberg_languages.csv")
metadata = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-06-03/gutenberg_metadata.csv")

# Pre-merge metadata and languages on gutenberg_id
metadata_lang = metadata.merge(languages, on="gutenberg_id", how="left")

# Merge with authors to include alias and language info in single DataFrame
full_df = metadata_lang.merge(authors, left_on="gutenberg_author_id", right_on="gutenberg_author_id", how="left")

# Now call list_authors passing the full merged dataframe as df
aliases = list_authors(by_languages=True, alias=True, df=full_df)

print(aliases)


# Plot average number of languages per author birth century
# Make sure df (author dataset) is loaded or replaced if needed
plot_avg_languages_by_birth_century(authors)
# Out:
# # conda environments:
# #
# base                   C:\Users\saran\miniconda3
# h501-gutenberg       * C:\Users\saran\miniconda3\envs\h501-gutenberg
#
# ...
