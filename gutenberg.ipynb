# %%
from tt_gutenberg.optional_task import plot_avg_languages_by_birth_century

plot_avg_languages_by_birth_century(df)
# Out:
# d:\Luddy\Data_Science\Projects\h501-gutenberg\tt_gutenberg\optional_task.py:29: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(data=century_avg, x='birth_century', y='avg_lang', ci=95)
